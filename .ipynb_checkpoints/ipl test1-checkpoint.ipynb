# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
matches=pd.read_csv('C:/Users/abine/OneDrive/Documents/Datasets/ipl/matches.csv')   
delivery=pd.read_csv('C:/Users/abine/OneDrive/Documents/Datasets/ipl/deliveries.csv')

# %%
matches.
# Out:
#       id  season           city        date                        team1  \
# 0      1    2017      Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017           Pune  2017-04-06               Mumbai Indians
# 2      3    2017         Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017         Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017      Bangalore  2017-04-08  Royal Challengers Bangalore
# 5      6    2017      Hyderabad  2017-04-09                Gujarat Lions
# 6      7    2017         Mumbai  2017-04-09        Kolkata Knight Riders
# 7      8    2017         Indore  2017-04-10  Royal Challengers Bangalore
# 8      9    2017           Pune  2017-04-11             Delhi Daredevils
# 9     10    2017         Mumbai  2017-04-12          Sunrisers Hyderabad
# 10    11    2017        Kolkata  2017-04-13              Kings XI Punjab
# 11    12    2017      Bangalore  2017-04-14  Royal Challengers Bangalore
# ...

# %%
delivery
# Out:
#         match_id  inning                 batting_team  \
# 0              1       1          Sunrisers Hyderabad
# 1              1       1          Sunrisers Hyderabad
# 2              1       1          Sunrisers Hyderabad
# 3              1       1          Sunrisers Hyderabad
# 4              1       1          Sunrisers Hyderabad
# 5              1       1          Sunrisers Hyderabad
# 6              1       1          Sunrisers Hyderabad
# 7              1       1          Sunrisers Hyderabad
# 8              1       1          Sunrisers Hyderabad
# 9              1       1          Sunrisers Hyderabad
# 10             1       1          Sunrisers Hyderabad
# 11             1       1          Sunrisers Hyderabad
# 12             1       1          Sunrisers Hyderabad
# 13             1       1          Sunrisers Hyderabad
# 14             1       1          Sunrisers Hyderabad
# 15             1       1          Sunrisers Hyderabad
# ...

# %%
filter=delivery["batting_team"]=="Gujarat Lions"
delivery.loc[delivery["is_super_over"]==1].where(filter)
# Out:
#         match_id  inning   batting_team    bowling_team  over  ball  \
# 8092         NaN     NaN            NaN             NaN   NaN   NaN
# 8093         NaN     NaN            NaN             NaN   NaN   NaN
# 8094         NaN     NaN            NaN             NaN   NaN   NaN
# 8095         NaN     NaN            NaN             NaN   NaN   NaN
# 8096         NaN     NaN            NaN             NaN   NaN   NaN
# 8097        34.0     4.0  Gujarat Lions  Mumbai Indians   1.0   1.0
# 8098        34.0     4.0  Gujarat Lions  Mumbai Indians   1.0   2.0
# 8099        34.0     4.0  Gujarat Lions  Mumbai Indians   1.0   3.0
# 8100        34.0     4.0  Gujarat Lions  Mumbai Indians   1.0   4.0
# 8101        34.0     4.0  Gujarat Lions  Mumbai Indians   1.0   5.0
# 8102        34.0     4.0  Gujarat Lions  Mumbai Indians   1.0   6.0
# 8103        34.0     4.0  Gujarat Lions  Mumbai Indians   1.0   7.0
# 8104        34.0     4.0  Gujarat Lions  Mumbai Indians   1.0   8.0
# ...

# %%
dir(pd)
# Out:
# ['Categorical',
#  'CategoricalDtype',
#  'CategoricalIndex',
#  'DataFrame',
#  'DateOffset',
#  'DatetimeIndex',
#  'DatetimeTZDtype',
#  'ExcelFile',
#  'ExcelWriter',
#  'Float64Index',
#  'Grouper',
#  'HDFStore',
#  'Index',
#  'IndexSlice',
#  'Int16Dtype',
#  'Int32Dtype',
#  'Int64Dtype',
#  'Int64Index',
#  'Int8Dtype',
#  'Interval',
#  'IntervalDtype',
#  'IntervalIndex',
#  'MultiIndex',
#  'NaT',
#  'Panel',
#  'Period',
#  'PeriodDtype',
#  'PeriodIndex',
#  'RangeIndex',
#  'Series',
#  'SparseArray',
#  'SparseDataFrame',
#  'SparseDtype',
#  'SparseSeries',
#  'TimeGrouper',
#  'Timedelta',
#  'TimedeltaIndex',
#  'Timestamp',
#  'UInt16Dtype',
#  'UInt32Dtype',
#  'UInt64Dtype',
#  'UInt64Index',
#  'UInt8Dtype',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__docformat__',
#  '__file__',
#  '__git_version__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_hashtable',
#  '_lib',
#  '_libs',
# ...

# %%
matches.sort_values(by="win_by_runs",ascending=False)
# Out:
#       id  season            city        date                        team1  \
# 43    44    2017           Delhi  2017-05-06               Mumbai Indians
# 619  620    2016       Bangalore  2016-05-14  Royal Challengers Bangalore
# 59    60    2008       Bangalore  2008-04-18        Kolkata Knight Riders
# 556  557    2015       Bangalore  2015-05-06  Royal Challengers Bangalore
# 410  411    2013       Bangalore  2013-04-23  Royal Challengers Bangalore
# 295  296    2011      Dharamsala  2011-05-17              Kings XI Punjab
# 114  115    2008          Mumbai  2008-05-30             Rajasthan Royals
# 182  183    2010           Delhi  2010-03-17               Mumbai Indians
# 8      9    2017            Pune  2017-04-11             Delhi Daredevils
# 541  542    2015         Chennai  2015-04-25          Chennai Super Kings
# 464  465    2014       Abu Dhabi  2014-04-21          Chennai Super Kings
# 131  132    2009  Port Elizabeth  2009-04-27               Mumbai Indians
# ...
