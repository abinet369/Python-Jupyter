# %%
import pandas as pd
sal=pd.read_csv(r'C:\Users\abine\OneDrive\Documents\Datasets\salaries\Salaries.csv')
sal
# Out:
#             Id            EmployeeName  \
# 0            1          NATHANIEL FORD
# 1            2            GARY JIMENEZ
# 2            3          ALBERT PARDINI
# 3            4       CHRISTOPHER CHONG
# 4            5         PATRICK GARDNER
# 5            6          DAVID SULLIVAN
# 6            7               ALSON LEE
# 7            8           DAVID KUSHNER
# 8            9          MICHAEL MORRIS
# 9           10      JOANNE HAYES-WHITE
# 10          11           ARTHUR KENNEY
# 11          12        PATRICIA JACKSON
# 12          13       EDWARD HARRINGTON
# 13          14             JOHN MARTIN
# 14          15          DAVID FRANKLIN
# 15          16         RICHARD CORRIEA
# 16          17                AMY HART
# 17          18          SEBASTIAN WONG
# 18          19              MARTY ROSS
# 19          20           ELLEN MOFFATT
# 20          21              VENUS AZAR
# 21          22            JUDY MELINEK
# 22          23           GEORGE GARCIA
# ...

# %%
sal.loc[sal["JobTitle"]=="CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)"][["Id","EmployeeName"]]
# Out:
#    Id        EmployeeName
# 9  10  JOANNE HAYES-WHITE

# %%
sal.query('BasePay>167000')
# Out:
#             Id             EmployeeName  \
# 0            1           NATHANIEL FORD
# 2            3           ALBERT PARDINI
# 7            8            DAVID KUSHNER
# 8            9           MICHAEL MORRIS
# 9           10       JOANNE HAYES-WHITE
# 10          11            ARTHUR KENNEY
# 12          13        EDWARD HARRINGTON
# 13          14              JOHN MARTIN
# 14          15           DAVID FRANKLIN
# 15          16          RICHARD CORRIEA
# 16          17                 AMY HART
# 18          19               MARTY ROSS
# 19          20            ELLEN MOFFATT
# 20          21               VENUS AZAR
# 21          22             JUDY MELINEK
# 23          24            VICTOR WYRSCH
# 25          26             GREGORY SUHR
# 27          28           RAYMOND GUZMAN
# 28          29           DENISE SCHMITT
# 29          30            MONICA FIELDS
# 30          31          HARLAN KELLY-JR
# 31          32              DAVID SHINN
# ...

# %%
sal.sort_values(by="Year",ascending=False)
# Out:
#             Id            EmployeeName  \
# 148653  148654               Joe Lopez
# 123244  123245          Fannie W Yeung
# 123242  123243        Nakeisha Peacock
# 123241  123242  Denise C Thomas-Wright
# 123240  123241            Carlene Boyd
# 123239  123240      Heather M Weisbrod
# 123238  123239           Jovan R Blake
# 123237  123238      Stefani O Harrison
# 123236  123237            Nakari Small
# 123235  123236         Derrick G Homer
# 123234  123235         Delphine Sedeno
# 123233  123234       Gasil E Aldepulla
# 123232  123233          Peter M Dayton
# 123231  123232         Gretchen A Rude
# 123230  123231         Aruna D Shankar
# 123229  123230         Corinne M Allen
# 123228  123229        Elizabeth Chavez
# 123243  123244            Edmund F Lee
# 123245  123246         Quindi L Berger
# 123189  123190       Robert E Thorstad
# 123246  123247           John P Howell
# 123261  123262    Elester T Westbrooks
# 123260  123261         Adam A Burleson
# ...

# %%
import pandas as pd
iris=pd.read_csv(r'C:\Users\abine\OneDrive\Documents\Datasets\Iris\Iris.csv')
iris
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# 5      6            5.4           3.9            1.7           0.4
# 6      7            4.6           3.4            1.4           0.3
# 7      8            5.0           3.4            1.5           0.2
# 8      9            4.4           2.9            1.4           0.2
# 9     10            4.9           3.1            1.5           0.1
# 10    11            5.4           3.7            1.5           0.2
# 11    12            4.8           3.4            1.6           0.2
# 12    13            4.8           3.0            1.4           0.1
# ...

# %%
iris.query('SepalLengthCm == 5.0|SepalLengthCm == 4.8')
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 4    5            5.0           3.6            1.4           0.2
# 7    8            5.0           3.4            1.5           0.2
# 11  12            4.8           3.4            1.6           0.2
# 12  13            4.8           3.0            1.4           0.1
# 24  25            4.8           3.4            1.9           0.2
# 25  26            5.0           3.0            1.6           0.2
# 26  27            5.0           3.4            1.6           0.4
# 30  31            4.8           3.1            1.6           0.2
# 35  36            5.0           3.2            1.2           0.2
# 40  41            5.0           3.5            1.3           0.3
# 43  44            5.0           3.5            1.6           0.6
# 45  46            4.8           3.0            1.4           0.3
# 49  50            5.0           3.3            1.4           0.2
# ...

# %%
iris.loc[(iris["SepalLengthCm"]==5.0)|(iris["SepalLengthCm"]==4.8)]
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 4    5            5.0           3.6            1.4           0.2
# 7    8            5.0           3.4            1.5           0.2
# 11  12            4.8           3.4            1.6           0.2
# 12  13            4.8           3.0            1.4           0.1
# 24  25            4.8           3.4            1.9           0.2
# 25  26            5.0           3.0            1.6           0.2
# 26  27            5.0           3.4            1.6           0.4
# 30  31            4.8           3.1            1.6           0.2
# 35  36            5.0           3.2            1.2           0.2
# 40  41            5.0           3.5            1.3           0.3
# 43  44            5.0           3.5            1.6           0.6
# 45  46            4.8           3.0            1.4           0.3
# 49  50            5.0           3.3            1.4           0.2
# ...

# %%
iris.pivot_table(index=["Species"],
                values=["SepalLengthCm"],
                 aggfunc="max")
# Out:
#                  SepalLengthCm
# Species
# Iris-setosa                5.8
# Iris-versicolor            7.0
# Iris-virginica             7.9

# %%
q=iris.groupby(iris["Species"])[["SepalLengthCm"]].max()
print(q)
q.values
# Out:
#                  SepalLengthCm
# Species
# Iris-setosa                5.8
# Iris-versicolor            7.0
# Iris-virginica             7.9
# array([[5.8],
#        [7. ],
#        [7.9]])

# %%
result=pd.DataFrame(q.values,
                   index=[['a','a','b'],q.index],
                   columns=['b'])
print(result)
# Out:
#                      b
#   Species
# a Iris-setosa      5.8
#   Iris-versicolor  7.0
# b Iris-virginica   7.9

# %%
re={"Benefits":123,"Status":"Active"}
sal.fillna(re)
# Out:
#             Id            EmployeeName  \
# 0            1          NATHANIEL FORD
# 1            2            GARY JIMENEZ
# 2            3          ALBERT PARDINI
# 3            4       CHRISTOPHER CHONG
# 4            5         PATRICK GARDNER
# 5            6          DAVID SULLIVAN
# 6            7               ALSON LEE
# 7            8           DAVID KUSHNER
# 8            9          MICHAEL MORRIS
# 9           10      JOANNE HAYES-WHITE
# 10          11           ARTHUR KENNEY
# 11          12        PATRICIA JACKSON
# 12          13       EDWARD HARRINGTON
# 13          14             JOHN MARTIN
# 14          15          DAVID FRANKLIN
# 15          16         RICHARD CORRIEA
# 16          17                AMY HART
# 17          18          SEBASTIAN WONG
# 18          19              MARTY ROSS
# 19          20           ELLEN MOFFATT
# 20          21              VENUS AZAR
# 21          22            JUDY MELINEK
# 22          23           GEORGE GARCIA
# ...

# %%
ind=['a','b','c','d']
arr=[0,1,2,3]
pd.Series(arr,ind)
#pd.DataFrame(arr)
# Out:
# a    0
# b    1
# c    2
# d    3
# dtype: int64

# %%
# Out:
#             Id            EmployeeName  \
# 0            1          NATHANIEL FORD
# 1            2            GARY JIMENEZ
# 2            3          ALBERT PARDINI
# 3            4       CHRISTOPHER CHONG
# 4            5         PATRICK GARDNER
# 5            6          DAVID SULLIVAN
# 6            7               ALSON LEE
# 7            8           DAVID KUSHNER
# 8            9          MICHAEL MORRIS
# 9           10      JOANNE HAYES-WHITE
# 10          11           ARTHUR KENNEY
# 11          12        PATRICIA JACKSON
# 12          13       EDWARD HARRINGTON
# 13          14             JOHN MARTIN
# 14          15          DAVID FRANKLIN
# 15          16         RICHARD CORRIEA
# 16          17                AMY HART
# 17          18          SEBASTIAN WONG
# 18          19              MARTY ROSS
# 19          20           ELLEN MOFFATT
# 20          21              VENUS AZAR
# 21          22            JUDY MELINEK
# 22          23           GEORGE GARCIA
# ...

# %%
q=sal.groupby(sal["Year"]).mean()[["TotalPayBenefits"]]
q
# Out:
#       TotalPayBenefits
# Year
# 2011      71744.103871
# 2012     100553.229232
# 2013     101440.519714
# 2014     100250.918884

# %%
pd.DataFrame(q.values,
            index=[[2000,2000,3000,3000],q.index],
            columns=['TotalPayBenefits'])
# Out:
#            TotalPayBenefits
#      Year
# 2000 2011      71744.103871
#      2012     100553.229232
# 3000 2013     101440.519714
#      2014     100250.918884

# %%
sal.pivot_table(index=['Year'],
           values=["TotalPayBenefits"],
           aggfunc='mean')
# Out:
#       TotalPayBenefits
# Year
# 2011      71744.103871
# 2012     100553.229232
# 2013     101440.519714
# 2014     100250.918884

# %%
sal.sort_values("TotalPayBenefits",ascending=False)
# Out:
#             Id            EmployeeName  \
# 0            1          NATHANIEL FORD
# 1            2            GARY JIMENEZ
# 110531  110532             David Shinn
# 110532  110533              Amy P Hart
# 110533  110534    William J Coaker Jr.
# 72925    72926          Gregory P Suhr
# 72926    72927    Joanne M Hayes-White
# 110534  110535          Gregory P Suhr
# 110535  110536    Joanne M Hayes-White
# 110536  110537         Ellen G Moffatt
# 36159    36160          Gary Altenberg
# 72927    72928             Samson  Lai
# 72928    72929         Ellen G Moffatt
# 110537  110538           John L Martin
# 110538  110539       Harlan L Kelly-Jr
# 72929    72930           Robert L Shaw
# 72930    72931        David L Franklin
# 72931    72932       Harlan L Kelly-Jr
# 110539  110540              Samson Lai
# 72932    72933           John L Martin
# 110540  110541        David L Franklin
# 36160    36161            Gregory Suhr
# 36161    36162              Khoa Trinh
# ...
