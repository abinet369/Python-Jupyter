# %%
import pandas as pd
iris=pd.read_csv(r'C:\Users\abine\OneDrive\Documents\Datasets\Iris\iras.csv')
iris
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# 5             5.4          3.9           1.7          0.4     Setosa
# 6             4.6          3.4           1.4          0.3     Setosa
# 7             5.0          3.4           1.5          0.2     Setosa
# 8             4.4          2.9           1.4          0.2     Setosa
# 9             4.9          3.1           1.5          0.1     Setosa
# 10            5.4          3.7           1.5          0.2     Setosa
# 11            4.8          3.4           1.6          0.2     Setosa
# 12            4.8          3.0           1.4          0.1     Setosa
# ...

# %%
#QUESTION 1
#Display Sepal length and petal length for all observations,whoose species is Virginica

# %%
iris.loc[(iris['variety']=='Virginica'),("sepal.length","petal.length")]
# Out:
#      sepal.length  petal.length
# 100           6.3           6.0
# 101           5.8           5.1
# 102           7.1           5.9
# 103           6.3           5.6
# 104           6.5           5.8
# 105           7.6           6.6
# 106           4.9           4.5
# 107           7.3           6.3
# 108           6.7           5.8
# 109           7.2           6.1
# 110           6.5           5.1
# 111           6.4           5.3
# 112           6.8           5.5
# 113           5.7           5.0
# 114           5.8           5.1
# 115           6.4           5.3
# 116           6.5           5.5
# 117           7.7           6.7
# 118           7.7           6.9
# 119           6.0           5.0
# 120           6.9           5.7
# 121           5.6           4.9
# 122           7.7           6.7
# 123           6.3           4.9
# 124           6.7           5.7
# 125           7.2           6.0
# 126           6.2           4.8
# 127           6.1           4.9
# ...

# %%
#QUESTION 2
#Display Sepal length ,petal length and species in descending order by sepal width and petal width
iris.sort_values(by=["sepal.width","petal.width"],ascending=False)[["sepal.length","petal.length"]]
# Out:
#      sepal.length  petal.length
# 15            5.7           1.5
# 33            5.5           1.4
# 32            5.2           1.5
# 14            5.8           1.2
# 5             5.4           1.7
# 16            5.4           1.3
# 117           7.7           6.7
# 131           7.9           6.4
# 44            5.1           1.9
# 18            5.7           1.7
# 19            5.1           1.5
# 46            5.1           1.6
# 21            5.1           1.5
# 10            5.4           1.5
# 48            5.3           1.5
# 109           7.2           6.1
# 4             5.0           1.4
# 22            4.6           1.0
# 37            4.9           1.4
# 43            5.0           1.6
# 17            5.1           1.4
# 40            5.0           1.3
# 0             5.1           1.4
# 27            5.2           1.5
# 36            5.5           1.3
# 136           6.3           5.6
# 148           6.2           5.4
# 85            6.0           4.5
# ...

# %%
#QUESTION 3
#Display Sepal length ,petal length and species where petal width are null
iris.loc[iris['petal.width'].isna()][["sepal.length","petal.length"]]
# Out:
# Empty DataFrame
# Columns: [sepal.length, petal.length]
# Index: []

# %%
#QUESTION 4
#Display Sepal length ,petal length and species where petal width are not null
iris.loc[iris['petal.width'].notna()][["sepal.length","petal.length"]]
# Out:
#      sepal.length  petal.length
# 0             5.1           1.4
# 1             4.9           1.4
# 2             4.7           1.3
# 3             4.6           1.5
# 4             5.0           1.4
# 5             5.4           1.7
# 6             4.6           1.4
# 7             5.0           1.5
# 8             4.4           1.4
# 9             4.9           1.5
# 10            5.4           1.5
# 11            4.8           1.6
# 12            4.8           1.4
# 13            4.3           1.1
# 14            5.8           1.2
# 15            5.7           1.5
# 16            5.4           1.3
# 17            5.1           1.4
# 18            5.7           1.7
# 19            5.1           1.5
# 20            5.4           1.7
# 21            5.1           1.5
# 22            4.6           1.0
# 23            5.1           1.7
# 24            4.8           1.9
# 25            5.0           1.6
# 26            5.0           1.6
# 27            5.2           1.5
# ...

# %%
#QUESTION 5
#Display Sepal length ,petal length and species for flowers who has sepal length either 5.0 or 4.8
iris.loc[(iris['sepal.length'] == 5.0)|(iris['sepal.length'] == 4.8)][["sepal.length","petal.length","variety"]]
# Out:
#     sepal.length  petal.length     variety
# 4            5.0           1.4      Setosa
# 7            5.0           1.5      Setosa
# 11           4.8           1.6      Setosa
# 12           4.8           1.4      Setosa
# 24           4.8           1.9      Setosa
# 25           5.0           1.6      Setosa
# 26           5.0           1.6      Setosa
# 30           4.8           1.6      Setosa
# 35           5.0           1.2      Setosa
# 40           5.0           1.3      Setosa
# 43           5.0           1.6      Setosa
# 45           4.8           1.4      Setosa
# 49           5.0           1.4      Setosa
# 60           5.0           3.5  Versicolor
# 93           5.0           3.3  Versicolor

# %%
#QUESTION 6
#species name with maximum sepal length
iris[['variety','sepal.length']].max()
# Out:
# variety         Virginica
# sepal.length          7.9
# dtype: object

# %%
#QUESTION 7
#details and  count total count per species
print(iris.groupby(iris['variety']).count())
#OR
iris["variety"].value_counts()
# Out:
#             sepal.length  sepal.width  petal.length  petal.width
# variety
# Setosa                50           50            50           50
# Versicolor            50           50            50           50
# Virginica             50           50            50           50
# Setosa        50
# Versicolor    50
# Virginica     50
# Name: variety, dtype: int64

# %%
#QUESTION 8
#each species max sepal length
print(iris.groupby(iris['variety']).max()[["sepal.length"]])
# Out:
#             sepal.length
# variety
# Setosa               5.8
# Versicolor           7.0
# Virginica            7.9

# %%
#QUESTION 9
#average petal width of each species
print(iris.groupby(iris['variety']).mean()[["petal.width"]])
# Out:
#             petal.width
# variety
# Setosa            0.246
# Versicolor        1.326
# Virginica         2.026

# %%
#QUESTION 10
#sort by column name
iris.sort_values(by=["sepal.width"],ascending=True)[["sepal.width"]]
# Out:
#      sepal.width
# 60           2.0
# 62           2.2
# 119          2.2
# 68           2.2
# 41           2.3
# 53           2.3
# 93           2.3
# 87           2.3
# 81           2.4
# 80           2.4
# 57           2.4
# 72           2.5
# 146          2.5
# 98           2.5
# 113          2.5
# 108          2.5
# 69           2.5
# 89           2.5
# 106          2.5
# 92           2.6
# 79           2.6
# 90           2.6
# 118          2.6
# 134          2.6
# 101          2.7
# 94           2.7
# 59           2.7
# 111          2.7
# 82           2.7
# 67           2.7
# ..           ...
# 85           3.4
# 39           3.4
# 148          3.4
# 28           3.4
# 26           3.4
# 43           3.5
# 40           3.5
# 36           3.5
# 27           3.5
# 0            3.5
# 17           3.5
# 37           3.6
# 22           3.6
# 4            3.6
# 109          3.6
# 48           3.7
# 10           3.7
# 21           3.7
# 46           3.8
# 44           3.8
# ...

# %%
#QUESTION 11
#Find the correlation coefficient between sepal length and petal length
iris['sepal.length'].corr(iris['petal.length'])
# Out:
# 0.8717537758865831
